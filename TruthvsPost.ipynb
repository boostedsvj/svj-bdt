# %%
from combine_hists import combine_npzs
import glob
import matplotlib.pyplot as plt
from matplotlib import colors
import numpy as np

# %%
mz250_post = combine_npzs(glob.glob('../Feb21_2022/postbdt_girthreweight/genjetpt375_mz250_mdark10_rinv0.3/*.npz'))
mz300_post = combine_npzs(glob.glob('../Feb21_2022/postbdt_girthreweight/genjetpt375_mz300_mdark10_rinv0.3/*.npz'))
mz350_post = combine_npzs(glob.glob('../Feb21_2022/postbdt_girthreweight/genjetpt375_mz350_mdark10_rinv0.3/*.npz'))
mz400_post = combine_npzs(glob.glob('../Feb21_2022/postbdt_girthreweight/genjetpt375_mz400_mdark10_rinv0.3/*.npz'))
mz450_post = combine_npzs(glob.glob('../Feb21_2022/postbdt_girthreweight/genjetpt375_mz450_mdark10_rinv0.3/*.npz'))
mz500_post = combine_npzs(glob.glob('../Feb21_2022/postbdt_girthreweight/genjetpt375_mz500_mdark10_rinv0.3/*.npz'))
mz550_post = combine_npzs(glob.glob('../Feb21_2022/postbdt_girthreweight/genjetpt375_mz550_mdark10_rinv0.3/*.npz'))

mz250_pre = combine_npzs(glob.glob('../Jan05_2022/prebdt/genjetpt375_mz250_mdark10_rinv0.3/*.npz'))['X']
mz300_pre = combine_npzs(glob.glob('../Jan05_2022/prebdt/genjetpt375_mz300_mdark10_rinv0.3/*.npz'))['X']
mz350_pre = combine_npzs(glob.glob('../Jan05_2022/prebdt/genjetpt375_mz350_mdark10_rinv0.3/*.npz'))['X']
mz400_pre = combine_npzs(glob.glob('../Jan05_2022/prebdt/genjetpt375_mz400_mdark10_rinv0.3/*.npz'))['X']
mz450_pre = combine_npzs(glob.glob('../Jan05_2022/prebdt/genjetpt375_mz450_mdark10_rinv0.3/*.npz'))['X']
mz500_pre = combine_npzs(glob.glob('../Jan05_2022/prebdt/genjetpt375_mz500_mdark10_rinv0.3/*.npz'))['X']
mz550_pre = combine_npzs(glob.glob('../Jan05_2022/prebdt/genjetpt375_mz550_mdark10_rinv0.3/*.npz'))['X']
mz550_post
# Out:
# {'score': array([0.68670636, 0.980415  , 0.00286184, ..., 0.86073357, 0.940631  ,
#         0.33213764], dtype=float32),
#  'mt': array([511.40009337, 413.77228519, 855.36913163, ..., 204.41022136,
#         360.80606294, 444.80078173]),
#  'rt': array([1.12492542, 1.30893229, 1.18012043, ..., 1.26376139, 1.17644585,
#         1.26614846]),
#  'pt': array([ 579.93043485,  391.36542388,  530.87426351, ...,  302.00516547,
#          589.08495052, 1072.14299354]),
#  'energy': array([1276.42407519,  702.06185433,  769.47553931, ...,  343.1771495 ,
#          859.50168071, 1291.64842925]),
#  'total': 27534,
#  '>=2jets': 27525,
#  'eta<2.4': 27047,
#  'trigger': 6283,
#  'ecf>0': 6184,
#  'rtx>1.1': 4004,
#  'nleptons==0': 3340,
#  'metfilter': 3339,
#  'preselection': 3339}

# %%
score=mz550_post['score']
pt = mz550_post['pt']
mz550_post['mt'][score>0.5 & pt>600]

# %%
score=mz550_post['score']
pt = mz550_post['pt']
#plt.hist(mz550_post['mt'][(score>0.2) & (pt>500)], bins=30, label='mz550 post: bdt>0.2', density=True)
plt.hist(mz550_post['mt'][(score>0.5) & (pt>500)], bins=30, label='mz550 post: bdt>0.5', alpha=0.5, density=True)
plt.hist(mz550_post['mt'][(score>0.7) & (pt>500)], bins=30, label='mz550 post: bdt>0.7', alpha=0.7, density=True)
plt.hist(mz550_pre[:,17], bins=30, label='mz550 truth matched', alpha=0.4, density=True)
plt.legend()
plt.title('Transverse Mass distribution: pre and post bdt files')
plt.show()
(pt > 500).sum() / pt.shape[0]
# Out:
# 0.32914046121593293

# %%
score=mz500_post['score']
plt.hist(mz500_post['mt'][score>0.2][pt>600], bins=40, label='mz500 post: bdt>0.2', density=True)
plt.hist(mz500_post['mt'][score>0.5][pt>600], bins=40, label='mz500 post: bdt>0.5', alpha=0.4, density=True)
plt.hist(mz500_post['mt'][score>0.7][pt>600], bins=40, label='mz500 post: bdt>0.7', alpha=0.4, density=True)
plt.hist(mz500_pre[:,17], bins=40, label='mz500 truth matched', alpha=0.4, density=True)
plt.legend()
plt.title('Transverse Mass distribution: pre and post bdt files')
plt.show()

# %%
score=mz450_post['score']
plt.hist(mz450_post['mt'][score>0.2][pt>600], bins=40, label='mz450 post: bdt>0.2', density=True)
plt.hist(mz450_post['mt'][score>0.5][pt>600], bins=40, label='mz450 post: bdt>0.5', alpha=0.4, density=True)
plt.hist(mz450_post['mt'][score>0.7][pt>600], bins=40, label='mz450 post: bdt>0.7', alpha=0.4, density=True)
plt.hist(mz450_pre[:,17], bins=40, label='mz450 truth matched', alpha=0.2, density=True)
plt.legend()
plt.title('Transverse Mass distribution: pre and post bdt files')
plt.show()

# %%
score=mz400_post['score']
plt.hist(mz400_post['mt'][score>0.2], bins=40, label='mz400 post: bdt>0.2', density=True)
plt.hist(mz400_post['mt'][score>0.5], bins=40, label='mz400 post: bdt>0.5', alpha=0.4, density=True)
plt.hist(mz400_post['mt'][score>0.7], bins=40, label='mz400 post: bdt>0.7', alpha=0.4, density=True)
plt.hist(mz400_pre[:,17], bins=40, label='mz400 truth matched', alpha=0.4, density=True)
plt.legend()
plt.title('Transverse Mass distribution: pre and post bdt files')
plt.show()

# %%
from scripts import combine_dirs_with_weights
ttjets_sel_eff = np.array([0.0004, 0.0014, 0.0012, 0.001, 0.0569, 0.1066, 0.1255, 0.0871])
ttjets_crosssections = np.array([87.339, 182.1642, 182.1642, 831.76, 1.808, 0.749, 0.22, 0.002])
ttjets_dirs = [
        '../Feb21_2022/postbdt_girthreweight/Autumn18.TTJets_DiLept_TuneCP5_13TeV-madgraphMLM-pythia8',
        '../Feb21_2022/postbdt_girthreweight/Autumn18.TTJets_SingleLeptFromTbar_TuneCP5_13TeV-madgraphMLM-pythia8',
        '../Feb21_2022/postbdt_girthreweight/Autumn18.TTJets_SingleLeptFromT_TuneCP5_13TeV-madgraphMLM-pythia8',
        '../Feb21_2022/postbdt_girthreweight/Autumn18.TTJets_TuneCP5_13TeV-madgraphMLM-pythia8',
        '../Feb21_2022/postbdt_girthreweight/Autumn18.TTJets_HT-600to800_TuneCP5_13TeV-madgraphMLM-pythia8',
        '../Feb21_2022/postbdt_girthreweight/Autumn18.TTJets_HT-800to1200_TuneCP5_13TeV-madgraphMLM-pythia8',
        '../Feb21_2022/postbdt_girthreweight/Autumn18.TTJets_HT-1200to2500_TuneCP5_13TeV-madgraphMLM-pythia8',
        '../Feb21_2022/postbdt_girthreweight/Autumn18.TTJets_HT-2500toInf_TuneCP5_13TeV-madgraphMLM-pythia8',
        ]
ttjets_weights = ttjets_crosssections*ttjets_sel_eff
ttjets_post = combine_dirs_with_weights(ttjets_dirs, ttjets_weights)

qcd_sel_eff = np.array([0.0023, 0.0442, 0.0656, 0.0516, 0.0438])
qcd_crossections = np.array([6826.0, 552.6, 156.6, 26.3, 7.5])
qcd_dirs = [
        '../Feb21_2022/postbdt_girthreweight/Autumn18.QCD_Pt_300to470_TuneCP5_13TeV_pythia8',
        '../Feb21_2022/postbdt_girthreweight/Autumn18.QCD_Pt_470to600_TuneCP5_13TeV_pythia8',
        '../Feb21_2022/postbdt_girthreweight/Autumn18.QCD_Pt_600to800_TuneCP5_13TeV_pythia8',
        '../Feb21_2022/postbdt_girthreweight/Autumn18.QCD_Pt_800to1000_TuneCP5_13TeV_pythia8_ext1',
        '../Feb21_2022/postbdt_girthreweight/Autumn18.QCD_Pt_1000to1400_TuneCP5_13TeV_pythia8',
        ]
qcd_weights = qcd_crossections*qcd_sel_eff
qcd_post = combine_dirs_with_weights(qcd_dirs, qcd_weights)
bkg = combine_dirs_with_weights(qcd_dirs+ttjets_dirs, np.concatenate((qcd_weights, ttjets_weights)))
score = bkg['score']
pt=bkg['pt']
plt.hist(bkg['mt'][(score>0.2) & (pt>500)], bins=40, label='mz400 post: bdt>0.2', density=True)
plt.show()
((pt > 500) & (score>0.2)).sum() / pt.shape[0]
# Out:
# Counts:
# 0 :     1125 available, using 95
# 1 :     4385 available, using 693
# 2 :     3720 available, using 594
# 3 :     2263 available, using 2263
# 4 :   104132 available, using 279
# 5 :   157563 available, using 217
# 6 :   138675 available, using 75
# 7 :    47264 available, using 0
# Counts:
# 0 :    20508 available, using 20508
# 1 :   271813 available, using 31905
# 2 :   338705 available, using 13419
# 3 :   265483 available, using 1772
# 4 :   183490 available, using 429
# Counts:
# 0 :    20508 available, using 20508
# 1 :   271813 available, using 31905
# 2 :   338705 available, using 13419
# 3 :   265483 available, using 1772
# 4 :   183490 available, using 429
# 5 :     1125 available, using 45
# 6 :     4385 available, using 333
# 7 :     3720 available, using 285
# 8 :     2263 available, using 1086
# 9 :   104132 available, using 134
# 10 :   157563 available, using 104
# 11 :   138675 available, using 36
# 12 :    47264 available, using 0
# 0.13066689505538426
